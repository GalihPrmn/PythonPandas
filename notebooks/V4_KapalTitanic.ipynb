# %%
import numpy as np
import pandas as pd

# %%
dataku = pd.read_csv('../data/kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
age = dataku['age']

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
age.median()
# Out:
# np.float64(28.0)

# %%
age.sum() # Data Kosong (NaN) akan di skip (Skipna=True)
# sum(age) -> kalo ini NaN nya gak di skip, akan menghasilkan nan
# Out:
# np.float64(21205.17)

# %%
clean_age = age.dropna() # Menghilangkan data NaN

# %%
clean_age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
dataku2 = dataku.dropna(thresh=7)

# Axis = 0 akan menghilangkan baris jika ada NaN , jika 1 maka akan menghilangkan kolom 
# thresh = 3 -> jika ada 3 data di baris NaN, maka akan dipertahankan

# %%
dataku2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku2 = dataku

# %%
dataku2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.age = dataku2.age.fillna(value=dataku2.age.mean())

# %%
dataku2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku2.age.values # Ubah dari PandasSeries Menjadi Array
# Out:
# array([22.        , 38.        , 26.        , 35.        , 35.        ,
#        29.69911765, 54.        ,  2.        , 27.        , 14.        ,
#         4.        , 58.        , 20.        , 39.        , 14.        ,
#        55.        ,  2.        , 29.69911765, 31.        , 29.69911765,
#        35.        , 34.        , 15.        , 28.        ,  8.        ,
#        38.        , 29.69911765, 19.        , 29.69911765, 29.69911765,
#        40.        , 29.69911765, 29.69911765, 66.        , 28.        ,
#        42.        , 29.69911765, 21.        , 18.        , 14.        ,
#        40.        , 27.        , 29.69911765,  3.        , 19.        ,
#        29.69911765, 29.69911765, 29.69911765, 29.69911765, 18.        ,
#         7.        , 21.        , 49.        , 29.        , 65.        ,
#        29.69911765, 21.        , 28.5       ,  5.        , 11.        ,
#        22.        , 38.        , 45.        ,  4.        , 29.69911765,
# ...

# %%
type(dataku.age.values)
# Out:
# numpy.ndarray
