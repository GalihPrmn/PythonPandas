# %%
import pandas as pd

# %%
dataku = pd.read_csv('../data/kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
data_baru = dataku[['age', 'fare']]

# %%
type(data_baru)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dataku[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
dataku[['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %% [markdown]
# # Dot Notation

# %%
dataku.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dataku.age.equals(dataku['age'])
# Out:
# True

# %% [markdown]
# # .iloc[baris, kolom]

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.iloc[0:10] #Mengambil baris dari index 0 sampai ke index 9
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
dataku.iloc[:,3] #Mengambil seluruh baris dan kolom index ke 3
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dataku.iloc[-5:] # Cari data dari index ke 5 terakhir dan ambil semuanya
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
dataku.iloc[[0,2,4,6]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E

# %%
dataku.iloc[[0,2,4,6], [0,2,3,6]]
# Out:
#    survived     sex   age     fare
# 0         0    male  22.0   7.2500
# 2         1  female  26.0   7.9250
# 4         0    male  35.0   8.0500
# 6         0    male  54.0  51.8625

# %% [markdown]
# # .loc['namaBaris', 'namaKolom'] - digunakan jika tidak tahu index

# %%
newData = pd.read_csv('../data/kapal_titanic.csv', index_col="embarked")

# %%
newData
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
newData.loc['S'] # Ambil data dengan isi S
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# S                0       1    male  54.0      0      0  51.8625    E
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  28.0      0      0  10.5000  NaN
# S                0       3    male  25.0      0      0   7.0500  NaN
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
#
# [644 rows x 8 columns]

# %%
newData.loc['S', 'age']
# Out:
# embarked
# S    22.0
# S    26.0
# S    35.0
# S    35.0
# S    54.0
#      ...
# S    28.0
# S    25.0
# S    27.0
# S    19.0
# S     NaN
# Name: age, Length: 644, dtype: float64

# %%
newData.loc['S', ['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# S         28.0  10.5000
# S         25.0   7.0500
# S         27.0  13.0000
# S         19.0  30.0000
# S          NaN  23.4500
#
# [644 rows x 2 columns]

# %%
newData.loc[['S', 'Q'], ['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# Q          NaN   7.7500
# Q          NaN   6.9500
# Q          NaN   7.7500
# Q         39.0  29.1250
# Q         32.0   7.7500
#
# [721 rows x 2 columns]
